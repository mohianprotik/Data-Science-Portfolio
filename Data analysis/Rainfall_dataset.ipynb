# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
import pandas as pd
import numpy as
 np


url='https://raw.githubusercontent.com/fazlyrabbi77/Climate-Science/master/Dhaka%20weather%201953-2016.csv'
df = pd.read_csv(url)
df
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      YEAR  Month  MaxTemp  MinTemp  RelativeHumidity  Rainfall
# 0    1953      1    26.70     10.9                70      10.0
# 1    1953      2    33.60     14.7                65       2.0
# 2    1953      3    37.50     21.7                73      90.0
# 3    1953      4    37.70     23.4                69      90.0
# 4    1953      5    34.70     24.2                81     274.0
# ..    ...    ...      ...      ...               ...       ...
# 763  2016      8    33.28     26.8                78     169.9
# 764  2016      9    32.87     26.6                82     138.5
# 765  2016     10    33.07     25.2                75      76.6
# 766  2016     11    29.60     20.2                73      24.1
# ...

# %%
#NULL value check
df.isnull().values.any()
# Out:
# False

# %%
#check all the statistics
df.describe()
# Out:
#               YEAR       Month  ...  RelativeHumidity    Rainfall
# count   768.000000  768.000000  ...        768.000000  768.000000
# mean   1984.500000    6.500000  ...         75.207031  168.377214
# std      18.484992    3.454302  ...          8.593081  173.784463
# min    1953.000000    1.000000  ...         49.000000    0.000000
# 25%    1968.750000    3.750000  ...         69.000000   13.000000
# 50%    1984.500000    6.500000  ...         76.000000  121.000000
# 75%    2000.250000    9.250000  ...         83.000000  273.250000
# max    2016.000000   12.000000  ...         90.000000  856.000000
#
# [8 rows x 6 columns]

# %%
correlation = df.corr()
plt.figure(figsize=(16,8))
sns.heatmap(correlation,annot=True,linewidth=0,vmin =-1,cmap = "RdBu_r")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
rain = df.groupby('Month')['Rainfall'].mean()
rain.plot(kind='bar')

# %%
#distribution plot
sns.distplot(rain)

# %%
#find the highest rainfall month
df.groupby('Month')['Rainfall'].mean().sort_values(ascending = False)
# Out:
# Month
# 7     382.076563
# 6     360.075000
# 8     313.971875
# 9     284.639063
# 5     271.131250
# 10    164.120312
# 4     126.431250
# 3      54.307812
# 11     28.017187
# 2      19.703125
# 12      9.271875
# 1       6.781250
# Name: Rainfall, dtype: float64

# %%
#boxplot of ALL data set
plt.figure(figsize=(16, 6))
ax = sns.boxplot(data=df, orient="h", palette="Set2")

# %%
#we can not predict if all the boxplot are shown all-together
#so we draw each set box plot separately

ax= sns.boxplot(x=df["Rainfall"])

# %%
#if we want to compare two variable relation boxplot can be handful
#here we will plot rel_humidity vs rainfall graph to see the relation between them

plt.figure(figsize=(16, 6)) #this is just to increase the size
ax =sns.boxplot(x="RelativeHumidity",y = "Rainfall", data =df)

# %%
#we can do catagorical boxplot of two variables

plt.figure(figsize=(16,6))
ax=sns.catplot(x="Month",y="Rainfall",kind="box", data =df)

# %%
plt.figure(figsize=(16,6))
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3628ccd9e8>,
# ...
#       dtype=object)
